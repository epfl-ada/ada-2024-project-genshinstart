# %%
# This code is for comparing the difference between AI generated paths, human navigated paths, and the actual shortest path

import pandas as pd
import networkx as nx
import os
import csv
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.spatial.distance import cosine
from sentence_transformers import SentenceTransformer


# load the links file
df = pd.read_csv('data/wikispeedia_paths-and-graph/links.tsv', sep='\t', comment='#', header=None, names=['origin', 'destination'])

# Create a directed graph
G = nx.from_pandas_edgelist(df, source='origin', target='destination', create_using=nx.DiGraph())

# load the origin and destination pairs, in the first column
ori_dest = pd.read_csv('ori_dest.csv').iloc[:, 0].tolist()
ori_dest = [eval(pair) for pair in ori_dest]

# %%
def load_ai_paths(folder, ori_dest):
    ai_paths = {}
    for pair in ori_dest:
        start_article, target_article = pair
        file = f'paths/{start_article}_{target_article}.csv' 
        if os.path.exists(file):
            with open(file, 'r') as f:
                paths = list(csv.reader(f))
                paths = [path for path in paths if path != [] and path[-1]==target_article]
                ai_paths[pair] = paths
    return ai_paths

def load_human_paths(ori_dest):
    human_paths = {}
    paths_df = pd.read_csv("data/wikispeedia_paths-and-graph/paths_finished.tsv", sep="\t", comment='#', header=None,
                       names=["hashedIpAddress", "timestamp", "durationInSec", "path", "rating"])
    for pair in ori_dest:
        human_paths[pair] = []
    for index, row in paths_df.iterrows():
        path = row['path']
        path = path.split(';')
        start_article = path[0]
        target_article = path[-1]
        if (start_article, target_article) in ori_dest:
            human_paths[(start_article, target_article)].append(path)
    return human_paths

def get_shortest_path(G, ori_dest):
    shortest_paths = {}
    for pair in ori_dest:
        start_article, target_article = pair
        try:
            shortest_path = nx.shortest_path(G, start_article, target_article)
            shortest_paths[pair] = [shortest_path]
        except nx.NetworkXNoPath:
            shortest_paths[pair] = []
    return shortest_paths

# %%
# for each pair, load the AI generated path and the human navigated path
AI_paths = load_ai_paths('paths', ori_dest)
human_paths = load_human_paths(ori_dest)
shortest_paths = get_shortest_path(G, ori_dest)

# %%
# print the average path length for each pair
for pair in ori_dest:
    start_article, target_article = pair
    ai_path = AI_paths[pair]
    human_path = human_paths[pair]
    shortest_path = shortest_paths[pair]
    # calculat the mean path length
    ai_path_len = sum([len(path) for path in ai_path]) / len(ai_path) if ai_path else 0
    human_path_len = sum([len(path) for path in human_path]) / len(human_path) if human_path else 0
    shortest_path_len = len(shortest_path[0]) if shortest_path else 0
    print(f"Start: {start_article}, Target: {target_article}")
    print(f"AI path length: {ai_path_len}, Human path length: {human_path_len}, Shortest path length: {shortest_path_len}")
# Out:
# Start: Brain, Target: Telephone
# AI path length: 5.6, Human path length: 7.1, Shortest path length: 4
# Start: Theatre, Target: Zebra
# AI path length: 8.6, Human path length: 7.83646408839779, Shortest path length: 4
# Start: Pyramid, Target: Bean
# AI path length: 5.6, Human path length: 8.246105919003115, Shortest path length: 4
# Start: Batman, Target: Wood
# AI path length: 7.5, Human path length: 7.263513513513513, Shortest path length: 4
# Start: Bird, Target: Great_white_shark
# AI path length: 9.6, Human path length: 5.695652173913044, Shortest path length: 4
# Start: Batman, Target: The_Holocaust
# AI path length: 5.4, Human path length: 5.420168067226891, Shortest path length: 4
# Start: Bird, Target: Adolf_Hitler
# AI path length: 5.0, Human path length: 5.401869158878505, Shortest path length: 3
# Start: Beer, Target: Sun
# AI path length: 7.6, Human path length: 5.181818181818182, Shortest path length: 3
# Start: Batman, Target: Banana
# AI path length: 6.0, Human path length: 7.260869565217392, Shortest path length: 5
# Start: Cat, Target: Computer
# AI path length: 3.0, Human path length: 7.192982456140351, Shortest path length: 3
# Start: Cat, Target: Microsoft
# AI path length: 7.0, Human path length: 8.196428571428571, Shortest path length: 4
# Start: Dog, Target: Telephone
# AI path length: 5.0, Human path length: 7.622641509433962, Shortest path length: 4
# Start: Flower, Target: Adolf_Hitler
# AI path length: 5.2, Human path length: 5.0588235294117645, Shortest path length: 4
# Start: Automobile, Target: Pluto
# AI path length: 5.0, Human path length: 5.787234042553192, Shortest path length: 4
# Start: Dog, Target: Venus
# AI path length: 11.2, Human path length: 7.25531914893617, Shortest path length: 4
# Start: Batman, Target: Bible
# AI path length: 4.0, Human path length: 5.790697674418604, Shortest path length: 4
# Start: Aluminium_chloride, Target: Parrot
# AI path length: 6.0, Human path length: 9.047619047619047, Shortest path length: 4
# Start: England, Target: God
# AI path length: 4.0, Human path length: 4.761904761904762, Shortest path length: 3
# Start: Achilles_tendon, Target: Ocean
# AI path length: 5.0, Human path length: 6.4, Shortest path length: 5
# Start: Calculus, Target: Paul_McCartney
# AI path length: 7.4, Human path length: 7.0, Shortest path length: 4
# Start: Aircraft, Target: Google
# AI path length: 0, Human path length: 9.342857142857143, Shortest path length: 4
# Start: Electricity, Target: God
# AI path length: 5.0, Human path length: 6.529411764705882, Shortest path length: 3
# Start: Art, Target: Mango
# AI path length: 8.8, Human path length: 9.53125, Shortest path length: 3
# Start: Brazil, Target: Hydrogen
# AI path length: 4.4, Human path length: 5.65625, Shortest path length: 3
# Start: Africa, Target: England
# AI path length: 3.0, Human path length: 4.333333333333333, Shortest path length: 3
# Start: Archbishop_of_Canterbury, Target: Vietnam
# AI path length: 5.0, Human path length: 6.566666666666666, Shortest path length: 4
# Start: Computer, Target: Russia
# AI path length: 4.6, Human path length: 4.827586206896552, Shortest path length: 3
# Start: Computer, Target: Fruit
# AI path length: 5.8, Human path length: 8.344827586206897, Shortest path length: 4
# Start: 14th_century, Target: Rainbow
# AI path length: 9.4, Human path length: 7.444444444444445, Shortest path length: 4
# Start: Cat, Target: Adolf_Hitler
# AI path length: 5.25, Human path length: 5.296296296296297, Shortest path length: 4
# Start: Jesus, Target: God
# AI path length: 2.0, Human path length: 2.0, Shortest path length: 2
# Start: Manchester, Target: Water
# AI path length: 5.0, Human path length: 6.1923076923076925, Shortest path length: 3
# Start: China, Target: Moon
# AI path length: 5.2, Human path length: 4.84, Shortest path length: 3
# Start: Antlion, Target: Hip_hop_music
# AI path length: 5.0, Human path length: 6.25, Shortest path length: 4
# Start: Batman, Target: Japan
# AI path length: 4.0, Human path length: 4.416666666666667, Shortest path length: 3
# Start: Batman, Target: Vitamin_D
# AI path length: 7.0, Human path length: 7.0, Shortest path length: 4
# Start: Batman, Target: Penguin
# AI path length: 14.5, Human path length: 7.875, Shortest path length: 5
# Start: Jesus, Target: Adolf_Hitler
# AI path length: 5.0, Human path length: 4.25, Shortest path length: 3
# Start: Achilles_tendon, Target: Ivory
# AI path length: 6.0, Human path length: 8.391304347826088, Shortest path length: 5
# Start: Batman, Target: Albert_Einstein
# AI path length: 4.6, Human path length: 4.478260869565218, Shortest path length: 4
# Start: Brothers_Grimm, Target: Windows_Vista
# AI path length: 6.0, Human path length: 8.869565217391305, Shortest path length: 5
# Start: Calculus, Target: Lemon
# AI path length: 8.5, Human path length: 8.380952380952381, Shortest path length: 4
# Start: California, Target: Adolf_Hitler
# AI path length: 4.0, Human path length: 4.761904761904762, Shortest path length: 3
# Start: Computer_programming, Target: Fresh_water
# AI path length: 7.4, Human path length: 8.619047619047619, Shortest path length: 5
# Start: Automobile, Target: Windows_XP
# AI path length: 5.0, Human path length: 6.15, Shortest path length: 5
# Start: Cat, Target: Dog
# AI path length: 12.5, Human path length: 2.55, Shortest path length: 2
# Start: Apple, Target: Banana
# AI path length: 3.0, Human path length: 3.0, Shortest path length: 3
# Start: China, Target: Afghanistan
# AI path length: 3.6, Human path length: 4.7368421052631575, Shortest path length: 3
# Start: God, Target: Adolf_Hitler
# AI path length: 5.0, Human path length: 4.631578947368421, Shortest path length: 4
# Start: Linux, Target: Adolf_Hitler
# AI path length: 5.0, Human path length: 5.684210526315789, Shortest path length: 4
# Start: Moon, Target: Mars
# AI path length: 3.0, Human path length: 3.0, Shortest path length: 2
# Start: Apple, Target: Fruit
# AI path length: 2.0, Human path length: 2.0, Shortest path length: 2
# Start: Bamako, Target: Sun
# AI path length: 6.4, Human path length: 6.888888888888889, Shortest path length: 4
# Start: Bird_migration, Target: Hubble_Space_Telescope
# AI path length: 14.75, Human path length: 6.166666666666667, Shortest path length: 4
# Start: Jew, Target: Telephone
# AI path length: 6.0, Human path length: 6.444444444444445, Shortest path length: 3
# Start: Video, Target: China
# AI path length: 4.0, Human path length: 6.5, Shortest path length: 4
# Start: Famine, Target: Arctic
# AI path length: 5.0, Human path length: 3.0, Shortest path length: 3
# Start: AIDS, Target: Jesus
# AI path length: 5.4, Human path length: 5.411764705882353, Shortest path length: 4
# Start: George_W._Bush, Target: Monkey
# AI path length: 4.6, Human path length: 10.588235294117647, Shortest path length: 4
# Start: Human, Target: Pluto
# AI path length: 7.75, Human path length: 5.647058823529412, Shortest path length: 3
# Start: Smog, Target: Toy_Story
# AI path length: 9.2, Human path length: 8.529411764705882, Shortest path length: 6
# Start: Pikachu, Target: Sun
# AI path length: 6.6, Human path length: 4.176470588235294, Shortest path length: 3
# Start: Earth, Target: Odysseus
# AI path length: 5.6, Human path length: 6.1875, Shortest path length: 4
# Start: 15th_century, Target: Windows_Vista
# AI path length: 8.0, Human path length: 7.625, Shortest path length: 4
# Start: Batman, Target: Peanut
# AI path length: 8.0, Human path length: 8.533333333333333, Shortest path length: 5
# Start: Bird, Target: Thomas_Jefferson
# AI path length: 5.2, Human path length: 6.733333333333333, Shortest path length: 3
# Start: Chemistry, Target: Fidel_Castro
# AI path length: 7.0, Human path length: 8.066666666666666, Shortest path length: 4
# Start: Dinosaur, Target: China
# AI path length: 2.0, Human path length: 3.2666666666666666, Shortest path length: 2
# Start: John_Dee, Target: China
# AI path length: 4.0, Human path length: 4.6, Shortest path length: 3
# Start: Reptile, Target: Jesus
# AI path length: 5.0, Human path length: 5.466666666666667, Shortest path length: 4
# Start: United_States, Target: English_language
# AI path length: 3.0, Human path length: 31.933333333333334, Shortest path length: 3
# Start: Adolf_Hitler, Target: Jesus
# AI path length: 3.0, Human path length: 4.6, Shortest path length: 3
# Start: Mario, Target: Nintendo
# AI path length: 2.0, Human path length: 5.266666666666667, Shortest path length: 2
# Start: Pikachu, Target: Jesus
# AI path length: 5.2, Human path length: 5.933333333333334, Shortest path length: 4
# Start: Africa, Target: Differential_equation
# AI path length: 6.0, Human path length: 7.642857142857143, Shortest path length: 4
# Start: Cat, Target: University
# AI path length: 5.0, Human path length: 7.5, Shortest path length: 4
# Start: Citrus, Target: Physics
# AI path length: 4.0, Human path length: 6.571428571428571, Shortest path length: 4
# Start: Computer, Target: Whale
# AI path length: 7.0, Human path length: 7.214285714285714, Shortest path length: 4
# Start: Dinosaur, Target: George_W._Bush
# AI path length: 3.4, Human path length: 4.428571428571429, Shortest path length: 3
# Start: England, Target: Train
# AI path length: 4.0, Human path length: 5.428571428571429, Shortest path length: 3
# Start: North_America, Target: Canada
# AI path length: 2.0, Human path length: 7.071428571428571, Shortest path length: 2
# Start: The_Godfather, Target: Neptune
# AI path length: 13.0, Human path length: 9.642857142857142, Shortest path length: 4
# Start: Volcano, Target: Alphabet
# AI path length: 6.0, Human path length: 5.642857142857143, Shortest path length: 3
# Start: Nintendo, Target: Snow
# AI path length: 9.5, Human path length: 5.857142857142857, Shortest path length: 3
# Start: Bangladesh, Target: Harry_S._Truman
# AI path length: 4.8, Human path length: 4.538461538461538, Shortest path length: 3
# Start: Computer, Target: Baseball
# AI path length: 12.4, Human path length: 7.6923076923076925, Shortest path length: 4
# Start: Electricity, Target: Anne_Frank
# AI path length: 10.6, Human path length: 6.076923076923077, Shortest path length: 4
# Start: Achilles, Target: Winston_Churchill
# AI path length: 3.8, Human path length: 5.166666666666667, Shortest path length: 3
# Start: Aircraft, Target: Yugoslavia
# AI path length: 4.0, Human path length: 5.416666666666667, Shortest path length: 3
# Start: AT%26T, Target: Vegetable
# AI path length: 4.0, Human path length: 5.416666666666667, Shortest path length: 4
# Start: Batman, Target: Jesus
# AI path length: 4.4, Human path length: 5.666666666666667, Shortest path length: 4
# Start: Beer, Target: Warsaw
# AI path length: 4.4, Human path length: 4.916666666666667, Shortest path length: 3
# Start: Colombia, Target: Meat
# AI path length: 4.0, Human path length: 8.75, Shortest path length: 3
# Start: Dog, Target: Sea
# AI path length: 5.2, Human path length: 6.083333333333333, Shortest path length: 3
# Start: England, Target: Japan
# AI path length: 3.2, Human path length: 4.0, Shortest path length: 3
# Start: Linguistics, Target: Rome
# AI path length: 4.0, Human path length: 5.333333333333333, Shortest path length: 4
# Start: Metal, Target: Prague
# AI path length: 4.2, Human path length: 7.333333333333333, Shortest path length: 4
# Start: Jesus, Target: Google
# AI path length: 7.25, Human path length: 8.25, Shortest path length: 4
# Start: History, Target: Nazi_Germany
# AI path length: 0, Human path length: 6.416666666666667, Shortest path length: 4
# Start: Fourteenth_Amendment_to_the_United_States_Constitution, Target: Reptile
# AI path length: 9.2, Human path length: 8.333333333333334, Shortest path length: 4
# Start: Arnold_Schwarzenegger, Target: Vegetable
# AI path length: 4.75, Human path length: 8.833333333333334, Shortest path length: 3
# Start: Google, Target: God
# AI path length: 6.4, Human path length: 6.166666666666667, Shortest path length: 3
# Start: Harry_Potter, Target: Kangaroo
# AI path length: 6.0, Human path length: 5.666666666666667, Shortest path length: 4
# Start: Acceleration, Target: Mozilla_Firefox
# AI path length: 7.6, Human path length: 9.090909090909092, Shortest path length: 5
# Start: Agriculture, Target: Sparrow
# AI path length: 7.0, Human path length: 7.909090909090909, Shortest path length: 4
# Start: Aircraft, Target: Solar_eclipse
# AI path length: 4.0, Human path length: 4.7272727272727275, Shortest path length: 3
# Start: Batman, Target: Superman
# AI path length: 2.0, Human path length: 2.0, Shortest path length: 2
# Start: Batman, Target: Bill_Clinton
# AI path length: 6.0, Human path length: 5.909090909090909, Shortest path length: 4
# Start: Batman, Target: Coconut_crab
# AI path length: 20.0, Human path length: 10.181818181818182, Shortest path length: 5
# Start: Brazil, Target: Vitamin
# AI path length: 6.6, Human path length: 6.363636363636363, Shortest path length: 4
# Start: Citrus, Target: Desert
# AI path length: 5.0, Human path length: 5.545454545454546, Shortest path length: 3
# Start: Continent, Target: Gorilla
# AI path length: 8.0, Human path length: 6.909090909090909, Shortest path length: 4
# Start: David_Beckham, Target: Great_white_shark
# AI path length: 10.0, Human path length: 9.545454545454545, Shortest path length: 5
# Start: Dog, Target: Elementary_algebra
# AI path length: 7.0, Human path length: 8.909090909090908, Shortest path length: 5
# Start: Flower, Target: George_H._W._Bush
# AI path length: 6.6, Human path length: 6.090909090909091, Shortest path length: 4
# Start: Forth, Target: Anne_Frank
# AI path length: 12.75, Human path length: 9.545454545454545, Shortest path length: 5
# Start: Mormon, Target: Ice
# AI path length: 6.6, Human path length: 8.454545454545455, Shortest path length: 4
# Start: Solar_System, Target: Babe_Ruth
# AI path length: 5.0, Human path length: 9.454545454545455, Shortest path length: 5
# Start: Ocean, Target: Love
# AI path length: 4.0, Human path length: 10.545454545454545, Shortest path length: 4
# Start: Seed, Target: New_York_City
# AI path length: 5.8, Human path length: 4.909090909090909, Shortest path length: 4
# Start: Weed, Target: Jesus
# AI path length: 7.666666666666667, Human path length: 7.363636363636363, Shortest path length: 5
# Start: Scent_of_a_Woman, Target: Firearm
# AI path length: 12.5, Human path length: 6.363636363636363, Shortest path length: 4
# Start: Meteorological_history_of_Hurricane_Katrina, Target: Iraq_War
# AI path length: 4.0, Human path length: 4.7272727272727275, Shortest path length: 4
# Start: Chocolate, Target: Velociraptor
# AI path length: 20.4, Human path length: 9.090909090909092, Shortest path length: 4
# Start: Mario, Target: God
# AI path length: 6.0, Human path length: 6.636363636363637, Shortest path length: 4
# Start: Age_of_Enlightenment, Target: Kazakhstan
# AI path length: 4.8, Human path length: 6.2, Shortest path length: 3
# Start: American_Civil_War, Target: Kuwait_City
# AI path length: 4.0, Human path length: 6.3, Shortest path length: 4
# Start: Anaconda, Target: Agnosticism
# AI path length: 5.0, Human path length: 6.4, Shortest path length: 3
# Start: Archbishop_of_Canterbury, Target: Neil_Armstrong
# AI path length: 7.2, Human path length: 10.4, Shortest path length: 4
# Start: California, Target: Middle_East
# AI path length: 3.6, Human path length: 5.0, Shortest path length: 3
# Start: Canada, Target: Pony
# AI path length: 14.0, Human path length: 7.6, Shortest path length: 4
# Start: Chemistry, Target: George_H._W._Bush
# AI path length: 5.0, Human path length: 6.6, Shortest path length: 4
# Start: Colombia, Target: 6th_century
# AI path length: 8.0, Human path length: 7.8, Shortest path length: 4
# Start: Dodo, Target: Film
# AI path length: 5.0, Human path length: 8.1, Shortest path length: 4
# Start: Dog, Target: Beer
# AI path length: 7.6, Human path length: 6.0, Shortest path length: 4
# Start: Germany, Target: Adolf_Hitler
# AI path length: 2.0, Human path length: 2.1, Shortest path length: 2
# Start: Global_warming, Target: Wood
# AI path length: 5.0, Human path length: 5.2, Shortest path length: 3
# Start: God, Target: Aztec
# AI path length: 9.0, Human path length: 7.7, Shortest path length: 4
# Start: Gregorian_chant, Target: Inductance
# AI path length: 8.6, Human path length: 9.1, Shortest path length: 5
# Start: Hydrogen, Target: Gold
# AI path length: 3.8, Human path length: 3.7, Shortest path length: 3
# Start: Judaism, Target: Flute
# AI path length: 6.4, Human path length: 7.9, Shortest path length: 4
# Start: Mathematics, Target: Juice
# AI path length: 11.0, Human path length: 10.9, Shortest path length: 4
# Start: Shark, Target: FIFA
# AI path length: 11.2, Human path length: 4.0, Shortest path length: 4
# Start: Booby, Target: Ununhexium
# AI path length: 8.6, Human path length: 8.1, Shortest path length: 5
# Start: Jesus, Target: Microsoft
# AI path length: 9.0, Human path length: 9.1, Shortest path length: 4
# Start: Pluto, Target: Wall_Street
# AI path length: 6.4, Human path length: 6.4, Shortest path length: 4
# Start: Brain, Target: DVD
# AI path length: 5.0, Human path length: 8.1, Shortest path length: 4
# Start: Planet, Target: Nuclear_power
# AI path length: 5.0, Human path length: 6.4, Shortest path length: 4
# Start: James_Bond, Target: Human_rights
# AI path length: 3.0, Human path length: 8.0, Shortest path length: 3
# Start: Pyramid, Target: Adolf_Hitler
# AI path length: 6.0, Human path length: 5.3, Shortest path length: 3
# Start: Tennis, Target: Nuclear_weapon
# AI path length: 4.8, Human path length: 5.8, Shortest path length: 3
# Start: Khudai_Khidmatgar, Target: Whale
# AI path length: 4.0, Human path length: 6.3, Shortest path length: 4
# Start: Earless_seal, Target: Citrus
# AI path length: 5.8, Human path length: 6.9, Shortest path length: 4
# Start: Wasp, Target: United_Arab_Emirates
# AI path length: 6.0, Human path length: 7.2, Shortest path length: 4
# Start: Weasel, Target: Barium
# AI path length: 8.4, Human path length: 9.6, Shortest path length: 5
# Start: Alpaca, Target: Nuclear_fission
# AI path length: 4.4, Human path length: 6.9, Shortest path length: 4
# Start: Australian_Open, Target: George_W._Bush
# AI path length: 4.0, Human path length: 5.2, Shortest path length: 4
# Start: Necktie, Target: Lion
# AI path length: 3.0, Human path length: 5.2, Shortest path length: 3
# Start: Sonic_the_Hedgehog_%28character%29, Target: Cancer
# AI path length: 8.2, Human path length: 6.1, Shortest path length: 3

# %%
# the x-axis is the path length, the y-axis is the pairs
# the color represents the type of path, AI generated path, human navigated path, or the actual shortest path

ai_path_len = [[len(path) for path in AI_paths[pair]] for pair in ori_dest]
human_path_len = [[len(path) for path in human_paths[pair]] for pair in ori_dest]
shortest_path_len = [[len(shortest_paths[pair][0])] for pair in ori_dest]

# Calculate mean values of AI path lengths and sort pairs based on these means
mean_ai_path_len = [np.mean(lengths) for lengths in ai_path_len]
sorted_indices = np.argsort(mean_ai_path_len)
sorted_ori_dest = [ori_dest[i] for i in sorted_indices]
sorted_ai_path_len = [ai_path_len[i] for i in sorted_indices]
sorted_human_path_len = [human_path_len[i] for i in sorted_indices]
sorted_shortest_path_len = [shortest_path_len[i] for i in sorted_indices]

# Set the style and color palette
sns.set(style="whitegrid")
palette = sns.color_palette("husl", 3)

# Adjust the figure size to lengthen the graph
plt.figure(figsize=(20, 30))

# Add jitter to the boxplot
def add_jitter(data, jitter_amount=0.1):
    return data + np.random.uniform(-jitter_amount, jitter_amount, size=len(data))

jittered_ai_path_len = [add_jitter(lengths) for lengths in sorted_ai_path_len]
jittered_human_path_len = [add_jitter(lengths) for lengths in sorted_human_path_len]
jittered_shortest_path_len = [add_jitter(lengths) for lengths in sorted_shortest_path_len]

# Plot AI and human paths in the same line for each pair
positions = np.array(range(len(sorted_ori_dest))) * 3.0
plt.boxplot(jittered_ai_path_len, positions=positions - 0.4, sym='', widths=0.6, vert=False, patch_artist=True,
            boxprops=dict(facecolor=palette[0], color=palette[0]),
            medianprops=dict(color='black'))
plt.boxplot(jittered_human_path_len, positions=positions + 0.4, sym='', widths=0.6, vert=False, patch_artist=True,
            boxprops=dict(facecolor=palette[1], color=palette[1]),
            medianprops=dict(color='black'))

# Plot shortest paths
plt.scatter(jittered_shortest_path_len, positions, color=palette[2], label='Shortest path', zorder=3)

# Create dummy plots for the legend
plt.plot([], [], color=palette[0], label='AI path')
plt.plot([], [], color=palette[1], label='Human path')

plt.yticks(positions, [f"{pair[0]}->{pair[1]}" for pair in sorted_ori_dest], rotation=45, ha='right')
plt.xlabel("Path length")
plt.ylabel("Pairs")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# d:\Anaconda\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# d:\Anaconda\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
def embedding_distance(node1, node2, embeddings):
    if node1 not in embeddings or node2 not in embeddings:
        return np.nan  
    return cosine(embeddings[node1], embeddings[node2])

def calculate_closeness_scores(path, embeddings):
    articles = path
    destination = articles[-1]  
    closeness_scores = []

    nodes_stack = []
    prev_node = articles[0]

    for i in range(1, len(articles)):
        current_node = articles[i]
        if current_node == '<' or current_node == 'back':
            try:
                current_node = nodes_stack.pop()
            except IndexError:
                raise ValueError("Back in the beginning")
        else:
            nodes_stack.append(prev_node)

        # Calculate the distance from the current node to the destination
        current_distance = embedding_distance(current_node, destination, embeddings)
        prev_distance = embedding_distance(prev_node, destination, embeddings)
        
        # Calculate the closeness score: distance difference from previous move
        closeness_score = prev_distance - current_distance
        closeness_scores.append(closeness_score)

        # Update the previous distance for the next move
        prev_node = current_node
        
    return closeness_scores

# Get Sentence embedding
model = SentenceTransformer('all-MiniLM-L6-v2')
sentence_embeddings = {node: model.encode(node.replace('_', ' ')) for node in G.nodes}

# %%
# Calculate closeness scores for AI paths and human paths
ai_closeness_scores = {}
human_closeness_scores = {}
optimal_closeness_scores = {}
for pair in ori_dest:
    start_article, target_article = pair
    ai_path = AI_paths[pair]
    human_path = human_paths[pair]
    ai_closeness_scores[pair] = [calculate_closeness_scores(path, sentence_embeddings) for path in ai_path]
    human_closeness_scores[pair] = [calculate_closeness_scores(path, sentence_embeddings) for path in human_path]
    optimal_closeness_scores[pair] = [calculate_closeness_scores(path, sentence_embeddings) for path in shortest_paths[pair]]

# Plot to show the difference in closeness scores distribution between AI paths and human paths
plt.figure(figsize=(10, 6))
ai_scores = [score for pair in ori_dest for score in ai_closeness_scores[pair]]
human_scores = [score for pair in ori_dest for score in human_closeness_scores[pair]]
optimal_scores = [score for pair in ori_dest for score in optimal_closeness_scores[pair]]
ai_scores = [score for sublist in ai_scores for score in sublist]
human_scores = [score for sublist in human_scores for score in sublist]
optimal_scores = [score for sublist in optimal_scores for score in sublist]
sns.kdeplot(ai_scores, label='AI path', color=palette[0])
sns.kdeplot(human_scores, label='Human path', color=palette[1])
sns.kdeplot(optimal_scores, label='Shortest path', color=palette[2])
plt.xlabel("Closeness score")
plt.ylabel("Density")
plt.legend()
plt.show()
